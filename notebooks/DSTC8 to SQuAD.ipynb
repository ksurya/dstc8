# %%
import json
import glob
from functools import lru_cache
from collections import OrderedDict, defaultdict
from copy import deepcopy
import numpy as np
from tqdm import tqdm_notebook as tqdm
from ipdb import set_trace
import re
import os

# %%
np.random.seed(1)

# %%
class Schemas(object):

    def __init__(self, filepath):
        with open(filepath) as f:
            self.index = {}
            for schema in json.load(f):
                service_name = schema["service_name"]
                self.index[service_name] = schema

    @lru_cache(maxsize=None)
    def get(self, service):
        result = dict(
            # service
            name=service,
            desc=self.index[service]["description"],
            
            # slots
            slot_name=[],
            slot_desc=[],
            slot_iscat=[], 
            slot_vals=[], # collected only for cat slots.. not sure if that makes sense

            # intents
            intent_name=[],
            intent_desc=[],
            intent_istrans=[],
            intent_reqslots=[],
            intent_optslots=[],
            intent_optvals=[],
        )

        for slot in self.index[service]["slots"]:
            result["slot_name"].append(slot["name"])
            result["slot_desc"].append(slot["description"])
            result["slot_iscat"].append(slot["is_categorical"])
            result["slot_vals"].append(slot["possible_values"])
        
        for intent in self.index[service]["intents"]:
            result["intent_name"].append(intent["name"])
            result["intent_desc"].append(intent["description"])
            result["intent_istrans"].append(intent["is_transactional"])
            result["intent_reqslots"].append(intent["required_slots"])
            result["intent_optslots"].append(list(intent["optional_slots"].keys()))
            result["intent_optvals"].append(list(intent["optional_slots"].values()))

        return result

# %%
# convert dial
def init_memory(schema, dial):
    # memory for cat slots: serv,slot=>[] or for noncat slots: noncat => []
    memory = defaultdict(list)
    index = defaultdict(set) # serv,slot->val, noncat->val
    
    for serv in dial["services"]:
        # add possible values from slot
        sch = schema.get(serv)
        for slot, iscat, slotvals in zip(sch["slot_name"], sch["slot_iscat"], sch["slot_vals"]):
            key = (serv, slot) if iscat else "noncat"
            for val in ["NONE", "dontcare"] + slotvals:
                if val not in index[key]:
                    index[key].add(val)
                    memory[key].append(val)
                        
        # add optional slot vals
        for optslots, optvals in zip(sch["intent_optslots"], sch["intent_optvals"]):
            for slot, val in zip(optslots, optvals):
                slotid = sch["slot_name"].index(slot)
                iscat = sch["slot_iscat"][slotid]
                assert slotid != -1
                key = (serv, slot) if iscat else "noncat"
                if val not in index[key]:
                    index[key].add(val)
                    memory[key].append(val)

    return memory, index


def update_memory(schema, dial_turn, memory, memory_index):
    # update only noncat values..
    utter = dial_turn["utterance"]
    for frame in dial_turn["frames"]:
        sch = schema.get(frame["service"])
        slot_names = sch["slot_name"]
        slot_iscat = sch["slot_iscat"]
        
        for tag in frame["slots"]:
            slot, st, en = tag["slot"], tag["start"], tag["exclusive_end"]
            slotid = slot_names.index(slot)
            iscat = slot_iscat[slotid]
            assert slotid != -1
            
            if not iscat:
                value = utter[st:en]
                key = "noncat"
                if value not in memory_index[key]:
                    value = re.sub("\u2013", "-", value) # dial 59_00125 turn 14
                    memory_index[key].add(value)
                    memory[key].append(value)


def memory_to_str(memory, key="noncat"):
    value = " . ".join(memory[key]) 
    return value


def query_to_str(items):
    return " . ".join(items)


def dial_to_samples(schema, dial):
    dial_id = dial["dialogue_id"]
    memory, memory_index = init_memory(schema, dial)    
    paragraphs = []
    
    for turnid, turn in enumerate(dial["turns"]):
        # memory comes from slot tagger
        update_memory(schema, turn, memory, memory_index)
        
        if turn["speaker"] == "USER":
            assert dial["turns"][turnid-1]["speaker"] == "SYSTEM"
            
            # utter info
            usr_utter = turn["utterance"]
            sys_utter = dial["turns"][turnid-1]["utterance"] if turnid > 0 else "dialogue started"
            turn_formatted = "this is turn number {}".format(turnid)
            
            # per turn QAS
            cat_qas = defaultdict(dict) # serv,slot->context,question,ans
            noncat_qas = dict(context=memory_to_str(memory), qas=[])
            
            for frame in turn["frames"]:
                serv = frame["service"]
                serv_desc = schema.get(serv)["desc"]
                
                # intent info
                intent = frame["state"]["active_intent"]
                if intent == "NONE":
                    intent_desc = "NONE"
                    intent_formatted = "there is no intent"
                else:
                    idx = schema.get(serv)["intent_name"].index(intent)
                    intent_desc = schema.get(serv)["intent_desc"][idx]
                    intent_trans = schema.get(serv)["intent_istrans"][idx]
                    if intent_trans:
                        intent_formatted = "intent is transactional"
                    else:
                        intent_formatted = "intent is not transactional"
                    assert idx != -1
                
                all_slots = schema.get(serv)["slot_name"]
                all_slots_desc = schema.get(serv)["slot_desc"]
                all_slots_iscat = schema.get(serv)["slot_iscat"] 
                active_slots = frame["state"]["slot_values"] # have values
                
                # fill active cat slots
                for slot, values in active_slots.items():
                    slot_idx = all_slots.index(slot)
                    slot_desc = all_slots_desc[slot_idx]
                    slot_iscat = all_slots_iscat[slot_idx]
                    
                    if slot_iscat:
                        context = memory_to_str(memory, key=(serv,slot))
                        
                        value = re.sub("\u2013", "-", values[0])
                        val_st = context.find(value)
                        val_en = val_st + len(value)
                        assert val_st != -1
                        assert context[val_st:val_en] == value
                        
                        formatted_info = "slot is categorical"
                        question_items = [turn_formatted, sys_utter, usr_utter, serv_desc, slot_desc, intent_desc, intent_formatted, formatted_info]
                        
                        cat_qas[serv, slot] = dict(context=context, qas=[])
                        cat_qas[serv, slot]["qas"].append(dict(
                            id="{}/{}/{}/{}".format(dial_id, turnid, serv, slot),
                            question=query_to_str(question_items),
                            answers=[dict(text=value, answer_start=val_st, answer_end=val_en)],
                            is_impossible=False,
                            is_cat=True,
                        ))
                        
                    else:
                        value = re.sub("\u2013", "-", values[0])
                        val_st = noncat_qas["context"].find(value)
                        val_en = val_st + len(value)
                        assert val_st != -1
                        assert noncat_qas["context"][val_st:val_en] == value
                        
                        formatted_info = "slot is not categorical"
                        question_items = [turn_formatted, sys_utter, usr_utter, serv_desc, slot_desc, intent_desc, intent_formatted, formatted_info]
                        
                        noncat_qas["qas"].append(dict(
                            id="{}/{}/{}/{}".format(dial_id, turnid, serv, slot),
                            question=query_to_str(question_items),
                            answers=[dict(text=value, answer_start=val_st, answer_end=val_en)],
                            is_impossible=False,
                            is_cat=False,
                        ))
                        
                
                # fill NONE valued slots, downsampled;
                for slot in set(all_slots) - set(active_slots):
                    slot_idx = all_slots.index(slot)
                    slot_desc = all_slots_desc[slot_idx]
                    slot_iscat = all_slots_iscat[slot_idx]
                    
                    num_cat_questions = 0
                    for x in cat_qas.values():
                        num_cat_questions += len(x["qas"])
                    
                    num_noncat_questions = len(noncat_qas["qas"])
                    
                    if slot_iscat and np.random.randn() > 0.5 and num_cat_questions < 2:
                        context = memory_to_str(memory, key=(serv,slot))
                        value = "NONE"
                        val_st = context.find(value)
                        val_en = val_st + len(value)
                        assert val_st != -1
                        assert context[val_st:val_en] == value
                        
                        formatted_info = "slot is categorical"
                        question_items = [turn_formatted, sys_utter, usr_utter, serv_desc, slot_desc, intent_desc, intent_formatted, formatted_info]
                        
                        cat_qas[serv, slot] = dict(context=context, qas=[])
                        cat_qas[serv, slot]["qas"].append(dict(
                            id="{}/{}/{}/{}".format(dial_id, turnid, serv, slot),
                            question=query_to_str(question_items),
                            answers=[dict(text=value, answer_start=val_st, answer_end=val_en)],
                            is_impossible=False,
                            is_cat=True,
                        ))
                        
                    elif not slot_iscat and np.random.randn() > 0.5 and num_noncat_questions < 2:
                        value = "NONE"
                        val_st = noncat_qas["context"].find(value)
                        val_en = val_st + len(value)
                        assert val_st != -1
                        assert noncat_qas["context"][val_st:val_en] == value
                        
                        formatted_info = "slot is not categorical"
                        question_items = [turn_formatted, sys_utter, usr_utter, serv_desc, slot_desc, intent_desc, intent_formatted, formatted_info]
                        
                        noncat_qas["qas"].append(dict(
                            id="{}/{}/{}/{}".format(dial_id, turnid, serv, slot),
                            question=query_to_str(question_items),
                            answers=[dict(text=value, answer_start=val_st, answer_end=val_en)],
                            is_impossible=False,
                            is_cat=False,
                        ))
            
            # push all turn paragraphs. ALL CAT and Non CAT questions are locally grouped
            paragraphs.append(dict(
                context=noncat_qas["context"], qas=noncat_qas["qas"],
            ))
            for x in cat_qas.values():
                paragraphs.append(dict(
                    context=x["context"], qas=x["qas"],
                ))

    return dict(
        title=dial_id,
        paragraphs=paragraphs,
    )

# %%
def create_dataset(mode):
    files = sorted(glob.glob(f"../data/{mode}/dialogues_*.json"))
    schema = Schemas(f"../data/{mode}/schema.json")
    dataset = {"version": "v0", "data": []}
    for filename in tqdm(files):
        with open(filename) as f:
            dial_list = json.load(f)
        for dial in dial_list:
            samples = dial_to_samples(schema, dial)
            dataset["data"].append(samples)
    return dataset


train_dataset = create_dataset("train")
dev_dataset = create_dataset("dev")
# Out:
# HBox(children=(IntProgress(value=0, max=127), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=20), HTML(value='')))

# %%
print(json.dumps(train_dataset["data"][0], indent=2))
# Out:
# {
#   "title": "1_00000",
#   "paragraphs": [
#     {
#       "context": "NONE . dontcare . Mexican . Chinese . Indian . American . Italian . 2019-03-01",
#       "qas": [
#         {
#           "id": "1_00000/0/Restaurants_1/date",
#           "question": "this is turn number 0 . dialogue started . I am feeling hungry so I would like to find a place to eat. . A leading provider for restaurant search and reservations . Date for the reservation or to find availability . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "NONE",
#               "answer_start": 0,
#               "answer_end": 4
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/0/Restaurants_1/cuisine",
#           "question": "this is turn number 0 . dialogue started . I am feeling hungry so I would like to find a place to eat. . A leading provider for restaurant search and reservations . Cuisine of food served in the restaurant . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "NONE",
#               "answer_start": 0,
#               "answer_end": 4
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . 1 . 2 . 3 . 4 . 5 . 6",
#       "qas": [
#         {
#           "id": "1_00000/0/Restaurants_1/party_size",
#           "question": "this is turn number 0 . dialogue started . I am feeling hungry so I would like to find a place to eat. . A leading provider for restaurant search and reservations . Party size for a reservation . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "NONE",
#               "answer_start": 0,
#               "answer_end": 4
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . Mexican . Chinese . Indian . American . Italian . 2019-03-01 . San Jose",
#       "qas": [
#         {
#           "id": "1_00000/2/Restaurants_1/city",
#           "question": "this is turn number 2 . Do you have a specific which you want the eating place to be located at? . I would like for it to be in San Jose. . A leading provider for restaurant search and reservations . City in which the restaurant is located . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "San Jose",
#               "answer_start": 81,
#               "answer_end": 89
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/2/Restaurants_1/date",
#           "question": "this is turn number 2 . Do you have a specific which you want the eating place to be located at? . I would like for it to be in San Jose. . A leading provider for restaurant search and reservations . Date for the reservation or to find availability . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "NONE",
#               "answer_start": 0,
#               "answer_end": 4
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . inexpensive . moderate . expensive . very expensive",
#       "qas": [
#         {
#           "id": "1_00000/2/Restaurants_1/price_range",
#           "question": "this is turn number 2 . Do you have a specific which you want the eating place to be located at? . I would like for it to be in San Jose. . A leading provider for restaurant search and reservations . Price range for the restaurant . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "NONE",
#               "answer_start": 0,
#               "answer_end": 4
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . True . False",
#       "qas": [
#         {
#           "id": "1_00000/2/Restaurants_1/serves_alcohol",
#           "question": "this is turn number 2 . Do you have a specific which you want the eating place to be located at? . I would like for it to be in San Jose. . A leading provider for restaurant search and reservations . Boolean flag indicating if the restaurant serves alcohol . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "NONE",
#               "answer_start": 0,
#               "answer_end": 4
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . Mexican . Chinese . Indian . American . Italian . 2019-03-01 . San Jose",
#       "qas": [
#         {
#           "id": "1_00000/4/Restaurants_1/city",
#           "question": "this is turn number 4 . Is there a specific cuisine type you enjoy, such as Mexican, Italian or something else? . I usually like eating the American type of food. . A leading provider for restaurant search and reservations . City in which the restaurant is located . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "San Jose",
#               "answer_start": 81,
#               "answer_end": 89
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/4/Restaurants_1/cuisine",
#           "question": "this is turn number 4 . Is there a specific cuisine type you enjoy, such as Mexican, Italian or something else? . I usually like eating the American type of food. . A leading provider for restaurant search and reservations . Cuisine of food served in the restaurant . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "American",
#               "answer_start": 47,
#               "answer_end": 55
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . Mexican . Chinese . Indian . American . Italian . 2019-03-01 . San Jose . 71 Saint Peter",
#       "qas": [
#         {
#           "id": "1_00000/6/Restaurants_1/city",
#           "question": "this is turn number 6 . I see that at 71 Saint Peter there is a good restaurant which is in San Jose. . Can you give me the address of this restaurant. . A leading provider for restaurant search and reservations . City in which the restaurant is located . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "San Jose",
#               "answer_start": 81,
#               "answer_end": 89
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/6/Restaurants_1/cuisine",
#           "question": "this is turn number 6 . I see that at 71 Saint Peter there is a good restaurant which is in San Jose. . Can you give me the address of this restaurant. . A leading provider for restaurant search and reservations . Cuisine of food served in the restaurant . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "American",
#               "answer_start": 47,
#               "answer_end": 55
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . inexpensive . moderate . expensive . very expensive",
#       "qas": [
#         {
#           "id": "1_00000/6/Restaurants_1/price_range",
#           "question": "this is turn number 6 . I see that at 71 Saint Peter there is a good restaurant which is in San Jose. . Can you give me the address of this restaurant. . A leading provider for restaurant search and reservations . Price range for the restaurant . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "NONE",
#               "answer_start": 0,
#               "answer_end": 4
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . Mexican . Chinese . Indian . American . Italian . 2019-03-01 . San Jose . 71 Saint Peter . 71 North San Pedro Street",
#       "qas": [
#         {
#           "id": "1_00000/8/Restaurants_1/city",
#           "question": "this is turn number 8 . If you want to go to this restaurant you can find it at 71 North San Pedro Street. . Can you give me the phone number that I can contact them with? . A leading provider for restaurant search and reservations . City in which the restaurant is located . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "San Jose",
#               "answer_start": 81,
#               "answer_end": 89
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/8/Restaurants_1/cuisine",
#           "question": "this is turn number 8 . If you want to go to this restaurant you can find it at 71 North San Pedro Street. . Can you give me the phone number that I can contact them with? . A leading provider for restaurant search and reservations . Cuisine of food served in the restaurant . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "American",
#               "answer_start": 47,
#               "answer_end": 55
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . True . False",
#       "qas": [
#         {
#           "id": "1_00000/8/Restaurants_1/has_live_music",
#           "question": "this is turn number 8 . If you want to go to this restaurant you can find it at 71 North San Pedro Street. . Can you give me the phone number that I can contact them with? . A leading provider for restaurant search and reservations . Boolean flag indicating if the restaurant has live music . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "NONE",
#               "answer_start": 0,
#               "answer_end": 4
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . Mexican . Chinese . Indian . American . Italian . 2019-03-01 . San Jose . 71 Saint Peter . 71 North San Pedro Street . 408-971-8523",
#       "qas": [
#         {
#           "id": "1_00000/10/Restaurants_1/city",
#           "question": "this is turn number 10 . If you want to phone them you can at 408-971-8523. . Is there some other restaurant which you can suggest? . A leading provider for restaurant search and reservations . City in which the restaurant is located . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "San Jose",
#               "answer_start": 81,
#               "answer_end": 89
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/10/Restaurants_1/cuisine",
#           "question": "this is turn number 10 . If you want to phone them you can at 408-971-8523. . Is there some other restaurant which you can suggest? . A leading provider for restaurant search and reservations . Cuisine of food served in the restaurant . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "American",
#               "answer_start": 47,
#               "answer_end": 55
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . inexpensive . moderate . expensive . very expensive",
#       "qas": [
#         {
#           "id": "1_00000/10/Restaurants_1/price_range",
#           "question": "this is turn number 10 . If you want to phone them you can at 408-971-8523. . Is there some other restaurant which you can suggest? . A leading provider for restaurant search and reservations . Price range for the restaurant . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "NONE",
#               "answer_start": 0,
#               "answer_end": 4
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . True . False",
#       "qas": [
#         {
#           "id": "1_00000/10/Restaurants_1/has_live_music",
#           "question": "this is turn number 10 . If you want to phone them you can at 408-971-8523. . Is there some other restaurant which you can suggest? . A leading provider for restaurant search and reservations . Boolean flag indicating if the restaurant has live music . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "NONE",
#               "answer_start": 0,
#               "answer_end": 4
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . Mexican . Chinese . Indian . American . Italian . 2019-03-01 . San Jose . 71 Saint Peter . 71 North San Pedro Street . 408-971-8523 . Bazille . Palo Alto",
#       "qas": [
#         {
#           "id": "1_00000/12/Restaurants_1/city",
#           "question": "this is turn number 12 . How would you like Bazille restaurant which is situated in San Jose. . Do you have another restaurant matching my needs? For example a restaurant which is economical and is located in Palo Alto. . A leading provider for restaurant search and reservations . City in which the restaurant is located . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "Palo Alto",
#               "answer_start": 162,
#               "answer_end": 171
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/12/Restaurants_1/cuisine",
#           "question": "this is turn number 12 . How would you like Bazille restaurant which is situated in San Jose. . Do you have another restaurant matching my needs? For example a restaurant which is economical and is located in Palo Alto. . A leading provider for restaurant search and reservations . Cuisine of food served in the restaurant . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "American",
#               "answer_start": 47,
#               "answer_end": 55
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . inexpensive . moderate . expensive . very expensive",
#       "qas": [
#         {
#           "id": "1_00000/12/Restaurants_1/price_range",
#           "question": "this is turn number 12 . How would you like Bazille restaurant which is situated in San Jose. . Do you have another restaurant matching my needs? For example a restaurant which is economical and is located in Palo Alto. . A leading provider for restaurant search and reservations . Price range for the restaurant . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "moderate",
#               "answer_start": 32,
#               "answer_end": 40
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . True . False",
#       "qas": [
#         {
#           "id": "1_00000/12/Restaurants_1/has_live_music",
#           "question": "this is turn number 12 . How would you like Bazille restaurant which is situated in San Jose. . Do you have another restaurant matching my needs? For example a restaurant which is economical and is located in Palo Alto. . A leading provider for restaurant search and reservations . Boolean flag indicating if the restaurant has live music . Find a restaurant of a particular cuisine in a city . intent is not transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "NONE",
#               "answer_start": 0,
#               "answer_end": 4
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . Mexican . Chinese . Indian . American . Italian . 2019-03-01 . San Jose . 71 Saint Peter . 71 North San Pedro Street . 408-971-8523 . Bazille . Palo Alto . Bird Dog",
#       "qas": [
#         {
#           "id": "1_00000/14/Restaurants_1/city",
#           "question": "this is turn number 14 . I see that 7 restaurants suit to what you requested. Bird Dog seems as a good restaurant and is located in Palo Alto. . Alright, that seems good. I would like to make a booking at this restaurant. . A leading provider for restaurant search and reservations . City in which the restaurant is located . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "Palo Alto",
#               "answer_start": 162,
#               "answer_end": 171
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/14/Restaurants_1/restaurant_name",
#           "question": "this is turn number 14 . I see that 7 restaurants suit to what you requested. Bird Dog seems as a good restaurant and is located in Palo Alto. . Alright, that seems good. I would like to make a booking at this restaurant. . A leading provider for restaurant search and reservations . Name of the restaurant . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "Bird Dog",
#               "answer_start": 174,
#               "answer_end": 182
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/14/Restaurants_1/cuisine",
#           "question": "this is turn number 14 . I see that 7 restaurants suit to what you requested. Bird Dog seems as a good restaurant and is located in Palo Alto. . Alright, that seems good. I would like to make a booking at this restaurant. . A leading provider for restaurant search and reservations . Cuisine of food served in the restaurant . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "American",
#               "answer_start": 47,
#               "answer_end": 55
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . inexpensive . moderate . expensive . very expensive",
#       "qas": [
#         {
#           "id": "1_00000/14/Restaurants_1/price_range",
#           "question": "this is turn number 14 . I see that 7 restaurants suit to what you requested. Bird Dog seems as a good restaurant and is located in Palo Alto. . Alright, that seems good. I would like to make a booking at this restaurant. . A leading provider for restaurant search and reservations . Price range for the restaurant . Reserve a table at a restaurant . intent is transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "moderate",
#               "answer_start": 32,
#               "answer_end": 40
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . 1 . 2 . 3 . 4 . 5 . 6",
#       "qas": [
#         {
#           "id": "1_00000/14/Restaurants_1/party_size",
#           "question": "this is turn number 14 . I see that 7 restaurants suit to what you requested. Bird Dog seems as a good restaurant and is located in Palo Alto. . Alright, that seems good. I would like to make a booking at this restaurant. . A leading provider for restaurant search and reservations . Party size for a reservation . Reserve a table at a restaurant . intent is transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "NONE",
#               "answer_start": 0,
#               "answer_end": 4
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . Mexican . Chinese . Indian . American . Italian . 2019-03-01 . San Jose . 71 Saint Peter . 71 North San Pedro Street . 408-971-8523 . Bazille . Palo Alto . Bird Dog . 11:30 am",
#       "qas": [
#         {
#           "id": "1_00000/16/Restaurants_1/city",
#           "question": "this is turn number 16 . For which time do you want the booking to be? . I will be eating there at 11:30 am so make it for then. . A leading provider for restaurant search and reservations . City in which the restaurant is located . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "Palo Alto",
#               "answer_start": 162,
#               "answer_end": 171
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/16/Restaurants_1/cuisine",
#           "question": "this is turn number 16 . For which time do you want the booking to be? . I will be eating there at 11:30 am so make it for then. . A leading provider for restaurant search and reservations . Cuisine of food served in the restaurant . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "American",
#               "answer_start": 47,
#               "answer_end": 55
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/16/Restaurants_1/restaurant_name",
#           "question": "this is turn number 16 . For which time do you want the booking to be? . I will be eating there at 11:30 am so make it for then. . A leading provider for restaurant search and reservations . Name of the restaurant . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "Bird Dog",
#               "answer_start": 174,
#               "answer_end": 182
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/16/Restaurants_1/time",
#           "question": "this is turn number 16 . For which time do you want the booking to be? . I will be eating there at 11:30 am so make it for then. . A leading provider for restaurant search and reservations . Time for the reservation or to find availability . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "11:30 am",
#               "answer_start": 185,
#               "answer_end": 193
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . inexpensive . moderate . expensive . very expensive",
#       "qas": [
#         {
#           "id": "1_00000/16/Restaurants_1/price_range",
#           "question": "this is turn number 16 . For which time do you want the booking to be? . I will be eating there at 11:30 am so make it for then. . A leading provider for restaurant search and reservations . Price range for the restaurant . Reserve a table at a restaurant . intent is transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "moderate",
#               "answer_start": 32,
#               "answer_end": 40
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . 1 . 2 . 3 . 4 . 5 . 6",
#       "qas": [
#         {
#           "id": "1_00000/16/Restaurants_1/party_size",
#           "question": "this is turn number 16 . For which time do you want the booking to be? . I will be eating there at 11:30 am so make it for then. . A leading provider for restaurant search and reservations . Party size for a reservation . Reserve a table at a restaurant . intent is transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "NONE",
#               "answer_start": 0,
#               "answer_end": 4
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . Mexican . Chinese . Indian . American . Italian . 2019-03-01 . San Jose . 71 Saint Peter . 71 North San Pedro Street . 408-971-8523 . Bazille . Palo Alto . Bird Dog . 11:30 am . today",
#       "qas": [
#         {
#           "id": "1_00000/18/Restaurants_1/cuisine",
#           "question": "this is turn number 18 . Can you please confirm that you want to book a table for 2 at 11:30 am at the Bird Dog restaurant in Palo Alto for today. . That suits me well. Can you tell me if they feature live music? . A leading provider for restaurant search and reservations . Cuisine of food served in the restaurant . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "American",
#               "answer_start": 47,
#               "answer_end": 55
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/18/Restaurants_1/city",
#           "question": "this is turn number 18 . Can you please confirm that you want to book a table for 2 at 11:30 am at the Bird Dog restaurant in Palo Alto for today. . That suits me well. Can you tell me if they feature live music? . A leading provider for restaurant search and reservations . City in which the restaurant is located . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "Palo Alto",
#               "answer_start": 162,
#               "answer_end": 171
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/18/Restaurants_1/date",
#           "question": "this is turn number 18 . Can you please confirm that you want to book a table for 2 at 11:30 am at the Bird Dog restaurant in Palo Alto for today. . That suits me well. Can you tell me if they feature live music? . A leading provider for restaurant search and reservations . Date for the reservation or to find availability . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "today",
#               "answer_start": 196,
#               "answer_end": 201
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/18/Restaurants_1/restaurant_name",
#           "question": "this is turn number 18 . Can you please confirm that you want to book a table for 2 at 11:30 am at the Bird Dog restaurant in Palo Alto for today. . That suits me well. Can you tell me if they feature live music? . A leading provider for restaurant search and reservations . Name of the restaurant . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "Bird Dog",
#               "answer_start": 174,
#               "answer_end": 182
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/18/Restaurants_1/time",
#           "question": "this is turn number 18 . Can you please confirm that you want to book a table for 2 at 11:30 am at the Bird Dog restaurant in Palo Alto for today. . That suits me well. Can you tell me if they feature live music? . A leading provider for restaurant search and reservations . Time for the reservation or to find availability . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "11:30 am",
#               "answer_start": 185,
#               "answer_end": 193
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . 1 . 2 . 3 . 4 . 5 . 6",
#       "qas": [
#         {
#           "id": "1_00000/18/Restaurants_1/party_size",
#           "question": "this is turn number 18 . Can you please confirm that you want to book a table for 2 at 11:30 am at the Bird Dog restaurant in Palo Alto for today. . That suits me well. Can you tell me if they feature live music? . A leading provider for restaurant search and reservations . Party size for a reservation . Reserve a table at a restaurant . intent is transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "2",
#               "answer_start": 22,
#               "answer_end": 23
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . inexpensive . moderate . expensive . very expensive",
#       "qas": [
#         {
#           "id": "1_00000/18/Restaurants_1/price_range",
#           "question": "this is turn number 18 . Can you please confirm that you want to book a table for 2 at 11:30 am at the Bird Dog restaurant in Palo Alto for today. . That suits me well. Can you tell me if they feature live music? . A leading provider for restaurant search and reservations . Price range for the restaurant . Reserve a table at a restaurant . intent is transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "moderate",
#               "answer_start": 32,
#               "answer_end": 40
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . Mexican . Chinese . Indian . American . Italian . 2019-03-01 . San Jose . 71 Saint Peter . 71 North San Pedro Street . 408-971-8523 . Bazille . Palo Alto . Bird Dog . 11:30 am . today",
#       "qas": [
#         {
#           "id": "1_00000/20/Restaurants_1/cuisine",
#           "question": "this is turn number 20 . Your booking has been made without errors, but unfortunately they do not have live music. . Will I be able to find liquor there? Can you give me the address of their location? . A leading provider for restaurant search and reservations . Cuisine of food served in the restaurant . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "American",
#               "answer_start": 47,
#               "answer_end": 55
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/20/Restaurants_1/city",
#           "question": "this is turn number 20 . Your booking has been made without errors, but unfortunately they do not have live music. . Will I be able to find liquor there? Can you give me the address of their location? . A leading provider for restaurant search and reservations . City in which the restaurant is located . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "Palo Alto",
#               "answer_start": 162,
#               "answer_end": 171
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/20/Restaurants_1/date",
#           "question": "this is turn number 20 . Your booking has been made without errors, but unfortunately they do not have live music. . Will I be able to find liquor there? Can you give me the address of their location? . A leading provider for restaurant search and reservations . Date for the reservation or to find availability . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "today",
#               "answer_start": 196,
#               "answer_end": 201
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/20/Restaurants_1/restaurant_name",
#           "question": "this is turn number 20 . Your booking has been made without errors, but unfortunately they do not have live music. . Will I be able to find liquor there? Can you give me the address of their location? . A leading provider for restaurant search and reservations . Name of the restaurant . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "Bird Dog",
#               "answer_start": 174,
#               "answer_end": 182
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/20/Restaurants_1/time",
#           "question": "this is turn number 20 . Your booking has been made without errors, but unfortunately they do not have live music. . Will I be able to find liquor there? Can you give me the address of their location? . A leading provider for restaurant search and reservations . Time for the reservation or to find availability . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "11:30 am",
#               "answer_start": 185,
#               "answer_end": 193
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . 1 . 2 . 3 . 4 . 5 . 6",
#       "qas": [
#         {
#           "id": "1_00000/20/Restaurants_1/party_size",
#           "question": "this is turn number 20 . Your booking has been made without errors, but unfortunately they do not have live music. . Will I be able to find liquor there? Can you give me the address of their location? . A leading provider for restaurant search and reservations . Party size for a reservation . Reserve a table at a restaurant . intent is transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "2",
#               "answer_start": 22,
#               "answer_end": 23
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . inexpensive . moderate . expensive . very expensive",
#       "qas": [
#         {
#           "id": "1_00000/20/Restaurants_1/price_range",
#           "question": "this is turn number 20 . Your booking has been made without errors, but unfortunately they do not have live music. . Will I be able to find liquor there? Can you give me the address of their location? . A leading provider for restaurant search and reservations . Price range for the restaurant . Reserve a table at a restaurant . intent is transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "moderate",
#               "answer_start": 32,
#               "answer_end": 40
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . Mexican . Chinese . Indian . American . Italian . 2019-03-01 . San Jose . 71 Saint Peter . 71 North San Pedro Street . 408-971-8523 . Bazille . Palo Alto . Bird Dog . 11:30 am . today . 420 Ramona Street",
#       "qas": [
#         {
#           "id": "1_00000/22/Restaurants_1/cuisine",
#           "question": "this is turn number 22 . The restaurant is located at 420 Ramona Street. Unfortunately they do not serve alcohol at the restaurant. . I appreciate it very much. That would be all. . A leading provider for restaurant search and reservations . Cuisine of food served in the restaurant . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "American",
#               "answer_start": 47,
#               "answer_end": 55
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/22/Restaurants_1/restaurant_name",
#           "question": "this is turn number 22 . The restaurant is located at 420 Ramona Street. Unfortunately they do not serve alcohol at the restaurant. . I appreciate it very much. That would be all. . A leading provider for restaurant search and reservations . Name of the restaurant . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "Bird Dog",
#               "answer_start": 174,
#               "answer_end": 182
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/22/Restaurants_1/city",
#           "question": "this is turn number 22 . The restaurant is located at 420 Ramona Street. Unfortunately they do not serve alcohol at the restaurant. . I appreciate it very much. That would be all. . A leading provider for restaurant search and reservations . City in which the restaurant is located . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "Palo Alto",
#               "answer_start": 162,
#               "answer_end": 171
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/22/Restaurants_1/date",
#           "question": "this is turn number 22 . The restaurant is located at 420 Ramona Street. Unfortunately they do not serve alcohol at the restaurant. . I appreciate it very much. That would be all. . A leading provider for restaurant search and reservations . Date for the reservation or to find availability . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "today",
#               "answer_start": 196,
#               "answer_end": 201
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         },
#         {
#           "id": "1_00000/22/Restaurants_1/time",
#           "question": "this is turn number 22 . The restaurant is located at 420 Ramona Street. Unfortunately they do not serve alcohol at the restaurant. . I appreciate it very much. That would be all. . A leading provider for restaurant search and reservations . Time for the reservation or to find availability . Reserve a table at a restaurant . intent is transactional . slot is not categorical",
#           "answers": [
#             {
#               "text": "11:30 am",
#               "answer_start": 185,
#               "answer_end": 193
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": false
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . 1 . 2 . 3 . 4 . 5 . 6",
#       "qas": [
#         {
#           "id": "1_00000/22/Restaurants_1/party_size",
#           "question": "this is turn number 22 . The restaurant is located at 420 Ramona Street. Unfortunately they do not serve alcohol at the restaurant. . I appreciate it very much. That would be all. . A leading provider for restaurant search and reservations . Party size for a reservation . Reserve a table at a restaurant . intent is transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "2",
#               "answer_start": 22,
#               "answer_end": 23
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     },
#     {
#       "context": "NONE . dontcare . inexpensive . moderate . expensive . very expensive",
#       "qas": [
#         {
#           "id": "1_00000/22/Restaurants_1/price_range",
#           "question": "this is turn number 22 . The restaurant is located at 420 Ramona Street. Unfortunately they do not serve alcohol at the restaurant. . I appreciate it very much. That would be all. . A leading provider for restaurant search and reservations . Price range for the restaurant . Reserve a table at a restaurant . intent is transactional . slot is categorical",
#           "answers": [
#             {
#               "text": "moderate",
#               "answer_start": 32,
#               "answer_end": 40
#             }
#           ],
#           "is_impossible": false,
#           "is_cat": true
#         }
#       ]
#     }
#   ]
# }

# %%
# all data
with open("../data/bert-all/train.json", "w") as f:
    json.dump(train_dataset, f, indent=2)
    
with open("../data/bert-all/dev.json", "w") as f:
    json.dump(dev_dataset, f, indent=2)

# %%
# smaller versions
if not os.path.exists("../data/bert-litmus/"):
    os.makedirs("../data/bert-litmus/")

with open("../data/bert-litmus/train.json", "w") as f:
    small = train_dataset["data"][:2]
    json.dump({"version": "v0-small", "data": small}, f, indent=2)
    
with open("../data/bert-litmus/dev.json", "w") as f:
    small = dev_dataset["data"][:2]
    json.dump({"version": "v0-small", "data": small}, f, indent=2)

# %%
# 10 dialogs
if not os.path.exists("../data/bert-10/"):
    os.makedirs("../data/bert-10/")

with open("../data/bert-10/train.json", "w") as f:
    json.dump({"version": "v0-10", "data": train_dataset["data"][:10]}, f, indent=2)
    
with open("../data/bert-10/dev.json", "w") as f:
    json.dump({"version": "v0-10", "data": dev_dataset["data"][:10]}, f, indent=2)

# %%
# 100 dialogs
if not os.path.exists("../data/bert-100/"):
    os.makedirs("../data/bert-100/")
    
with open("../data/bert-100/train.json", "w") as f:
    json.dump({"version": "v0-10", "data": train_dataset["data"][:100]}, f, indent=2)
    
with open("../data/bert-100/dev.json", "w") as f:
    json.dump({"version": "v0-10", "data": dev_dataset["data"][:100]}, f, indent=2)
